# %% [markdown]
# # Task A Colab quickstart
#
# Thin launcher notebook for the Task A baseline pipeline. Keep all training and decomposition logic in `scripts/` and `src/`.

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
REPO_URL = "https://github.com/TheoHLong/reading-the-weights.git"
# !git clone $REPO_URL
# %cd reading-the-weights

# %%
# !bash scripts/setup_colab.sh

# %%
# !python scripts/train_baseline.py --config configs/baselines/mnist_baseline.yaml

# %%
# Replace the checkpoint path below after training.
# !python scripts/analyze_checkpoint.py --checkpoint checkpoints/REPLACE_ME.pt
