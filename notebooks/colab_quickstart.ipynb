# %% [markdown]
# # Colab quickstart\n\nThin notebook for running the project in Colab. Core logic stays in `scripts/` and `src/`.\n

# %%
from google.colab import drive\ndrive.mount("/content/drive")\n

# %%
# Replace with your own GitHub URL before running.\nREPO_URL = "https://github.com/your-user/reading-the-weights.git"\n!git clone $REPO_URL\n%cd reading-the-weights\n

# %%
# !bash scripts/setup_colab.sh\n

# %%
# !python scripts/train_mnist.py --config configs/mnist_baseline.yaml\n

# %%
# After training, replace the checkpoint path below.\n!python scripts/analyze_mnist.py --checkpoint checkpoints/REPLACE_ME.pt\n
